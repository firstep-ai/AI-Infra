# %%
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
client = OpenAI()

response = client.responses.create(
    model="o4-mini-2025-04-16",
    input=[
        {
            "role": "user",
            "content": [
                {
                    "type": "input_text",
                    "text": "Write a one-sentence bedtime story about a unicorn.",
                }
            ],
        },
    ],
    max_completion_tokens=100
)

print(response.output_text)
# Out:
# Running cells with '.venv (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/zhipeng.wang/Documents/GitHub/AI-Infra/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
