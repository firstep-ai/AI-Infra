# %%
vllm serve /proj-tango-pvc/users/zhipeng.wang/workspace/models/Qwen3-Omni-30B-A3B-Instruct --omni --port 8091

# %%
python openai_chat_completion_client_for_multimodal_generation.py --query-type use_video --video-path sample_demo_2.mp4 --prompt "explain this video" --model /proj-tango-pvc/users/zhipeng.wang/workspace/models/Qwen3-Omni-30B-A3B-Instruct
