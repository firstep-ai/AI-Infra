# %%
git clone -b releases/v0.10.2 https://github.com/vllm-project/vllm.git

# %%
vllm serve naver-clova-ix/donut-base-finetuned-docvqa --served-model-name naver-clova-ix--donut-base-finetuned-docvqa --hf_overrides {"architectures": ["DonutForConditionalGeneration"]} --max_num_seqs 2 --chat-template ./chat_templates/template_alpaca.jinja

# %%
from openai import OpenAI

openai_api_key = "EMPTY"
openai_api_base = "http://localhost:8000/v1"
client = OpenAI(api_key=openai_api_key, base_url=openai_api_base)

image_url = "https://huggingface.co/datasets/hf-internal-testing/example-documents/resolve/main/jpeg_images/0.jpg"

chat_response = client.chat.completions.create(
    model="naver-clova-ix--donut-base-finetuned-docvqa",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "What time is the coffee break?"},
                {"type": "image_url", "image_url": {"url": image_url}},
            ],
        }
    ]
)
print(chat_response.choices[0].message.content)
