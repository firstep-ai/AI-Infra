# %%
uv pip install -v --no-build-isolation https://github.com/microsoft/antares/releases/download/v0.9.6/autort-0.9.6.4.4+cuda.zip

# %%
/vllm/compilation/cuda_graph.py:301 -- 打开这个文件，找到 entry.cudagraph.replay() 那行，在那行之前添加 debug function（以后记得还要删除）
+ print('===============', entry.output.shape)
+ import autort; autort.perform(lambda: entry.cudagraph.replay(), 10); exit(0)
entry.cudagraph.replay()

# %%
(Worker_TP3_EP3 pid=901559) -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  
(Worker_TP3_EP3 pid=901559)                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls  
(Worker_TP3_EP3 pid=901559) -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  
(Worker_TP3_EP3 pid=901559)                                         cudaGraphLaunch        23.01%     125.198ms        63.09%     343.289ms      34.329ms       0.000us         0.00%       0.000us       0.000us            10  
(Worker_TP3_EP3 pid=901559)                                     Command Buffer Full        52.59%     286.167ms        52.59%     286.167ms      35.771ms       0.000us         0.00%       0.000us       0.000us             8  
(Worker_TP3_EP3 pid=901559)                                   cudaDeviceSynchronize        22.07%     120.073ms        22.07%     120.073ms     120.073ms       0.000us         0.00%       0.000us       0.000us             1  
(Worker_TP3_EP3 pid=901559)                                            Buffer Flush         1.80%       9.785ms        14.56%      79.250ms      39.625ms       0.000us         0.00%       0.000us       0.000us             2  
(Worker_TP3_EP3 pid=901559)                                 Activity Buffer Request         0.53%       2.894ms         0.53%       2.894ms       1.447ms       0.000us         0.00%       0.000us       0.000us             2  
(Worker_TP3_EP3 pid=901559)                                   cudaStreamIsCapturing         0.01%      29.205us         0.01%      29.205us       2.921us       0.000us         0.00%       0.000us       0.000us            10  
(Worker_TP3_EP3 pid=901559)                                    cudaDriverGetVersion         0.00%       1.010us         0.00%       1.010us       0.101us       0.000us         0.00%       0.000us       0.000us            10  
(Worker_TP3_EP3 pid=901559) triton_poi_fused_add_all_reduce_bitwise_and_bitwise_...         0.00%       0.000us         0.00%       0.000us       0.000us      19.296us         0.00%      19.296us       1.930us            10  
(Worker_TP3_EP3 pid=901559) void vllm::cross_device_reduce_1stage<__nv_bfloat16,...         0.00%       0.000us         0.00%       0.000us       0.000us      64.933ms        14.00%      64.933ms      52.791us          1230  
(Worker_TP3_EP3 pid=901559)      triton_red_fused__to_copy_add_mean_mul_pow_rsqrt_1         0.00%       0.000us         0.00%       0.000us       0.000us      32.574us         0.01%      32.574us       3.257us            10  
(Worker_TP3_EP3 pid=901559) void per_token_group_quant_8bit_kernel<c10::BFloat16...         0.00%       0.000us         0.00%       0.000us       0.000us      10.152ms         2.19%      10.152ms       1.859us          5460  
(Worker_TP3_EP3 pid=901559) void deep_gemm::transpose_fp32<512u, 64u, 56u, 57u>(...         0.00%       0.000us         0.00%       0.000us       0.000us       3.690ms         0.80%       3.690ms       1.531us          2410  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 2112u, 7...         0.00%       0.000us         0.00%       0.000us       0.000us      10.578ms         2.28%      10.578ms      17.342us           610  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 128u, 71...         0.00%       0.000us         0.00%       0.000us       0.000us       5.261ms         1.13%       5.261ms       8.625us           610  
(Worker_TP3_EP3 pid=901559)                                      triton_red_fused_2         0.00%       0.000us         0.00%       0.000us       0.000us      29.344us         0.01%      29.344us       2.934us            10  
(Worker_TP3_EP3 pid=901559) void deep_gemm::transpose_fp32<512u, 64u, 12u, 13u>(...         0.00%       0.000us         0.00%       0.000us       0.000us       1.492ms         0.32%       1.492ms       1.223us          1220  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 3072u, 1...         0.00%       0.000us         0.00%       0.000us       0.000us       4.187ms         0.90%       4.187ms       6.865us           610  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 8192u, 1...         0.00%       0.000us         0.00%       0.000us       0.000us       5.438ms         1.17%       5.438ms       8.914us           610  
(Worker_TP3_EP3 pid=901559)                                      triton_poi_fused_3         0.00%       0.000us         0.00%       0.000us       0.000us      15.488us         0.00%      15.488us       1.549us            10  
(Worker_TP3_EP3 pid=901559)                                      triton_poi_fused_4         0.00%       0.000us         0.00%       0.000us       0.000us     953.366us         0.21%     953.366us       1.563us           610  
(Worker_TP3_EP3 pid=901559)                                      triton_poi_fused_5         0.00%       0.000us         0.00%       0.000us       0.000us     809.079us         0.17%     809.079us       1.326us           610  
(Worker_TP3_EP3 pid=901559)                nvjet_tst_64x8_64x16_1x1_v_bz_splitK_TNT         0.00%       0.000us         0.00%       0.000us       0.000us       2.720ms         0.59%       2.720ms       4.460us           610  
(Worker_TP3_EP3 pid=901559) void cublasLt::splitKreduce_kernel<32, 16, int, floa...         0.00%       0.000us         0.00%       0.000us       0.000us       3.408ms         0.73%       3.408ms       2.864us          1190  
(Worker_TP3_EP3 pid=901559)             triton_poi_fused_addmm_mul_unsqueeze_view_6         0.00%       0.000us         0.00%       0.000us       0.000us      11.680us         0.00%      11.680us       1.168us            10  
(Worker_TP3_EP3 pid=901559) void vllm::indexer_k_quant_and_cache_kernel<__nv_bfl...         0.00%       0.000us         0.00%       0.000us       0.000us       1.065ms         0.23%       1.065ms       1.746us           610  
(Worker_TP3_EP3 pid=901559) void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us       1.112ms         0.24%       1.112ms       0.934us          1190  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_paged_mqa_logits<1u, 64u, 1...         0.00%       0.000us         0.00%       0.000us       0.000us       4.854ms         1.05%       4.854ms       7.957us           610  
(Worker_TP3_EP3 pid=901559) void deep_gemm::smxx_clean_logits<1u, 8192u, 8u>(uns...         0.00%       0.000us         0.00%       0.000us       0.000us       4.054ms         0.87%       4.054ms       6.646us           610  
(Worker_TP3_EP3 pid=901559) void vllm::topKPerRowDecode<512>(float const*, int c...         0.00%       0.000us         0.00%       0.000us       0.000us      58.637ms        12.64%      58.637ms      96.126us           610  
(Worker_TP3_EP3 pid=901559)                       nvjet_tst_64x8_64x16_2x1_v_bz_TNT         0.00%       0.000us         0.00%       0.000us       0.000us       2.128ms         0.46%       2.128ms       3.488us           610  
(Worker_TP3_EP3 pid=901559)               _convert_req_index_to_global_index_kernel         0.00%       0.000us         0.00%       0.000us       0.000us     799.230us         0.17%     799.230us       1.310us           610  
(Worker_TP3_EP3 pid=901559) void at::native::(anonymous namespace)::CatArrayBatc...         0.00%       0.000us         0.00%       0.000us       0.000us       1.185ms         0.26%       1.185ms       1.942us           610  
(Worker_TP3_EP3 pid=901559) void vllm::concat_and_cache_ds_mla_kernel<__nv_bfloa...         0.00%       0.000us         0.00%       0.000us       0.000us       1.013ms         0.22%       1.013ms       1.661us           610  
(Worker_TP3_EP3 pid=901559) void sm90::flash_fwd_splitkv_mla_fp8_sparse_kernel<T...         0.00%       0.000us         0.00%       0.000us       0.000us      14.816ms         3.19%      14.816ms      24.288us           610  
(Worker_TP3_EP3 pid=901559) void flash_fwd_mla_combine_kernel<cutlass::bfloat16_...         0.00%       0.000us         0.00%       0.000us       0.000us      20.399ms         4.40%      20.399ms      33.442us           610  
(Worker_TP3_EP3 pid=901559)                       nvjet_tst_64x8_64x16_2x1_v_bz_NNT         0.00%       0.000us         0.00%       0.000us       0.000us       2.112ms         0.46%       2.112ms       3.462us           610  
(Worker_TP3_EP3 pid=901559) void deep_gemm::transpose_fp32<512u, 64u, 16u, 17u>(...         0.00%       0.000us         0.00%       0.000us       0.000us     731.070us         0.16%     731.070us       1.198us           610  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 7168u, 2...         0.00%       0.000us         0.00%       0.000us       0.000us       4.405ms         0.95%       4.405ms       7.221us           610  
(Worker_TP3_EP3 pid=901559) triton_red_fused__to_copy_add_empty_like_mean_mul_pe...         0.00%       0.000us         0.00%       0.000us       0.000us     118.367us         0.03%     118.367us       3.946us            30  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 4608u, 7...         0.00%       0.000us         0.00%       0.000us       0.000us     544.769us         0.12%     544.769us      18.159us            30  
(Worker_TP3_EP3 pid=901559) triton_poi_fused_empty_like_mul_per_token_group_fp8_...         0.00%       0.000us         0.00%       0.000us       0.000us      33.760us         0.01%      33.760us       1.125us            30  
(Worker_TP3_EP3 pid=901559) void deep_gemm::transpose_fp32<512u, 64u, 18u, 19u>(...         0.00%       0.000us         0.00%       0.000us       0.000us      38.366us         0.01%      38.366us       1.279us            30  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 7168u, 2...         0.00%       0.000us         0.00%       0.000us       0.000us     239.676us         0.05%     239.676us       7.989us            30  
(Worker_TP3_EP3 pid=901559)      triton_red_fused__to_copy_add_mean_mul_pow_rsqrt_2         0.00%       0.000us         0.00%       0.000us       0.000us       2.625ms         0.57%       2.625ms       4.303us           610  
(Worker_TP3_EP3 pid=901559)                                      triton_red_fused_3         0.00%       0.000us         0.00%       0.000us       0.000us       1.946ms         0.42%       1.946ms       3.243us           600  
(Worker_TP3_EP3 pid=901559)                                      triton_poi_fused_6         0.00%       0.000us         0.00%       0.000us       0.000us     840.287us         0.18%     840.287us       1.400us           600  
(Worker_TP3_EP3 pid=901559)             triton_poi_fused_addmm_mul_unsqueeze_view_7         0.00%       0.000us         0.00%       0.000us       0.000us     728.420us         0.16%     728.420us       1.214us           600  
(Worker_TP3_EP3 pid=901559) triton_red_fused__to_copy_add_mean_moe_forward_share...         0.00%       0.000us         0.00%       0.000us       0.000us       2.181ms         0.47%       2.181ms       3.760us           580  
(Worker_TP3_EP3 pid=901559)                                           memcpy32_post         0.00%       0.000us         0.00%       0.000us       0.000us       1.170ms         0.25%       1.170ms       1.009us          1160  
(Worker_TP3_EP3 pid=901559)                nvjet_tst_64x8_64x16_4x1_v_bz_splitK_TNT         0.00%       0.000us         0.00%       0.000us       0.000us       2.716ms         0.59%       2.716ms       4.682us           580  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 512u, 71...         0.00%       0.000us         0.00%       0.000us       0.000us       5.814ms         1.25%       5.814ms      10.025us           580  
(Worker_TP3_EP3 pid=901559)                             triton_poi_fused__to_copy_0         0.00%       0.000us         0.00%       0.000us       0.000us     931.322us         0.20%     931.322us       1.606us           580  
(Worker_TP3_EP3 pid=901559) void vllm::moe::topk_with_k2_kernel<__nv_bfloat16>(_...         0.00%       0.000us         0.00%       0.000us       0.000us       1.045ms         0.23%       1.045ms       1.802us           580  
(Worker_TP3_EP3 pid=901559) void vllm::moe::group_idx_and_topk_idx_kernel<__nv_b...         0.00%       0.000us         0.00%       0.000us       0.000us       4.349ms         0.94%       4.349ms       7.498us           580  
(Worker_TP3_EP3 pid=901559) void at::native::vectorized_elementwise_kernel<8, at...         0.00%       0.000us         0.00%       0.000us       0.000us       1.538ms         0.33%       1.538ms       2.652us           580  
(Worker_TP3_EP3 pid=901559) void at::native::vectorized_elementwise_kernel<8, at...         0.00%       0.000us         0.00%       0.000us       0.000us     774.044us         0.17%     774.044us       1.335us           580  
(Worker_TP3_EP3 pid=901559) void at::native::vectorized_elementwise_kernel<8, at...         0.00%       0.000us         0.00%       0.000us       0.000us     914.297us         0.20%     914.297us       1.576us           580  
(Worker_TP3_EP3 pid=901559) void deep_gemm::transpose_fp32<512u, 64u, 2u, 3u>(fl...         0.00%       0.000us         0.00%       0.000us       0.000us     755.106us         0.16%     755.106us       1.302us           580  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 7168u, 2...         0.00%       0.000us         0.00%       0.000us       0.000us       2.042ms         0.44%       2.042ms       3.520us           580  
(Worker_TP3_EP3 pid=901559)                                _count_expert_num_tokens         0.00%       0.000us         0.00%       0.000us       0.000us     903.195us         0.19%     903.195us       1.557us           580  
(Worker_TP3_EP3 pid=901559)                                _fwd_kernel_ep_scatter_1         0.00%       0.000us         0.00%       0.000us       0.000us     672.602us         0.14%     672.602us       1.160us           580  
(Worker_TP3_EP3 pid=901559)                                _fwd_kernel_ep_scatter_2         0.00%       0.000us         0.00%       0.000us       0.000us       1.987ms         0.43%       1.987ms       3.426us           580  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 4096u, 7...         0.00%       0.000us         0.00%       0.000us       0.000us     106.232ms        22.90%     106.232ms     183.158us           580  
(Worker_TP3_EP3 pid=901559) void vllm::act_and_mul_kernel<c10::BFloat16, &(c10::...         0.00%       0.000us         0.00%       0.000us       0.000us      20.358ms         4.39%      20.358ms      35.099us           580  
(Worker_TP3_EP3 pid=901559) void per_token_group_quant_8bit_kernel<c10::BFloat16...         0.00%       0.000us         0.00%       0.000us       0.000us      13.113ms         2.83%      13.113ms      22.609us           580  
(Worker_TP3_EP3 pid=901559) void deep_gemm::sm90_fp8_gemm_1d2d_impl<0u, 7168u, 2...         0.00%       0.000us         0.00%       0.000us       0.000us      54.897ms        11.83%      54.897ms      94.650us           580  
(Worker_TP3_EP3 pid=901559)                                   _fwd_kernel_ep_gather         0.00%       0.000us         0.00%       0.000us       0.000us       2.706ms         0.58%       2.706ms       4.666us           580  
(Worker_TP3_EP3 pid=901559)                   triton_poi_fused_add_all_reduce_mul_1         0.00%       0.000us         0.00%       0.000us       0.000us     652.572us         0.14%     652.572us       1.125us           580  
(Worker_TP3_EP3 pid=901559) -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  
(Worker_TP3_EP3 pid=901559) Self CPU time total: 544.147ms
(Worker_TP3_EP3 pid=901559) Self CUDA time total: 463.906ms
