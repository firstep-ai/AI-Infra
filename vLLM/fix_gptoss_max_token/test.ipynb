# %%
CUDA_VISIBLE_DEVICES=2 .venv/bin/python -m vllm.entrypoints.openai.api_server \
    --model /proj-tango-pvc/users/zhipeng.wang/workspace/models/gpt-oss-20b \
    --port 8000 \
    --trust-remote-code \
    --enforce-eager \
    --enable-auto-tool-choice \
    --tool-call-parser openai

# %%
curl http://localhost:8000/v1/chat/completions \
  -H "Content-Type: application/json" \
  -d '{
    "model": "/proj-tango-pvc/users/zhipeng.wang/workspace/models/gpt-oss-20b",
    "messages": [{"role": "user", "content": "What is the role of AI in medicine?"}],
    "reasoning_effort": "medium",
    "max_tokens": 300
  }'

# %%
curl http://localhost:8000/v1/responses \
  -H "Content-Type: application/json" \
  -d '{
    "model": "/proj-tango-pvc/users/zhipeng.wang/workspace/models/gpt-oss-20b",
    "input": "What is the role of AI in medicine?",
    "reasoning": {"effort": "medium"},
    "max_output_tokens": 300
  }'
