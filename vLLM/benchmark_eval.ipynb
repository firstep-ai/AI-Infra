# %% [markdown]
# ## vLLM测试随机输入

# %%
vllm bench serve --model deepseek --num-prompts 1000 --random-input-len 256 --random-output-len 100 --ignore-eos

# %% [markdown]
# ## SGL测试随机输入

# %%
python -m sglang.bench_serving --backend sglang --model deepseek --dataset-name random --num-prompts 1000 --random-input-len 256 --random-output-len 100 --random-range-ratio 1 --profile

# %% [markdown]
# ## SGL测试真实workload

# %%
python3 -m sglang.bench_serving --backend sglang --dataset-name mooncake --dataset-path /proj-tango-pvc/users/zhipeng.wang/workspace/CXD/synthetic_mooncake_trace.jsonl --mooncake-slowdown-factor 1.0 --mooncake-num-rounds 1 --tokenizer /proj-tango-pvc/users/zhipeng.wang/workspace/models/rakutenai-3-0-alpha

# %%
vllm bench serve --model /proj-tango-pvc/users/frd_eng/models/meti/distillation/large_part0_run0/bck/checkpoint-1550/safetensors_test_johanes --num-prompts 1000 --random-input-len 653 --random-output-len 113 --ignore-eos
